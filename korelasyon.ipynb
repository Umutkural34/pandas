# %% [markdown]
# # KORELASYON NEDİR ?

# %% [raw]
# Korelasyon analizi; değişkenler arasındaki ilişki, bu ilişkinin yönü ve şiddeti ile ilgili bilgiler sağlayan istatiksel bir yöntemdir.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("GBvideos.csv")

# %%
df
# Out:
#           video_id trending_date  \
# 0      Jw1Y-zhQURU      17.14.11
# 1      3s1rvMFUweQ      17.14.11
# 2      n1WpP7iowLc      17.14.11
# 3      PUTEiSjKwJU      17.14.11
# 4      rHwDegptbI4      17.14.11
# ...            ...           ...
# 38911  l884wKofd54      18.14.06
# 38912  IP8k2xkhOdI      18.14.06
# 38913  Il-an3K9pjg      18.14.06
# 38914  -DRsfNObKIQ      18.14.06
# 38915  4YFo4bdMO8Q      18.14.06
#
#                                                    title  \
# 0          John Lewis Christmas Ad 2017 - #MozTheMonster
# 1              Taylor Swift: …Ready for It? (Live) - SNL
# 2             Eminem - Walk On Water (Audio) ft. Beyoncé
# 3      Goals from Salford City vs Class of 92 and Fri...
# 4      Dashcam captures truck's near miss with child ...
# ...                                                  ...
# 38911  Enrique Iglesias - MOVE TO MIAMI (Official Vid...
# 38912  Jacob Sartorius - Up With It (Official Music V...
# ...

# %%
# yukardaki tabloda videoların beğeni sayısı ile görüntülenme sayısı arasında ne kadar kuvvetli ilişki 
# olduğuna bakalım ve bu ilişkinin yönünü bulalım ... (corr komutu ile bakıyoruz ...)

df[["views","likes"]].corr()
# Out:
#           views     likes
# views  1.000000  0.795862
# likes  0.795862  1.000000

# %% [raw]
# Görüntülenme ve beğeni arasındaki ilişki yaklaşık olarak 0.79 hesaplanmıştır.Pozitif yönlü (görüntülenme arttıkça beğeni artar)
# iyi bir ilişki olduğu söylenebilir.
#
# ! Korelasyon katsayısı -1 ile +1 arasında değerler alır. Mutlak değer ne kadar büyükse ilişki o kadar kuvvetlidir...

# %%
# şimdide beğeni , beğenmeme(dislike) , yorum sayısı ve görüntülenme sayıları arasındaki bu 4 sütunun korelasyonuna 
# birden bakalım ...

df[["views","likes","dislikes","comment_count"]].corr()
# Out:
#                   views     likes  dislikes  comment_count
# views          1.000000  0.795862  0.392407       0.466899
# likes          0.795862  1.000000  0.446746       0.744361
# dislikes       0.392407  0.446746  1.000000       0.771772
# comment_count  0.466899  0.744361  0.771772       1.000000

# %% [raw]
# Tabloya bakıldığı zaman görüntülenme ve beğenmeme(dislike) korelasyon katsayısı yaklaşık olarak 0.39 , beğenme ve beğenmeme
# arasındaki korelasyon katsayısı yaklaşık olarak 0.44 olarak hesaplanmıştır. Bu ikililer arasında orta düzey pozitif yönlü bir
# ilişki olduğu söylenebilir...
#
# Yine tabloya baktığımız zaman beğenmeme ve yorum sayısı arasındaki korelasyon katsayısı yaklaşık olarak 0.77 , beğenme ve yorum
# sayısı arasındaki korelaasyon katsayısı yaklaşık olara 0.74 hesaplanmıştır. Bu ikililer arasında iyi düzeyde pozitif yönlü bir ilişki olduğu yorumu yapılabilir ...
